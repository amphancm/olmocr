# %%
#%%capture
# !apt-get update -y

# !apt-get install -y poppler-utils ttf-mscorefonts-installer msttcorefonts fonts-crosextra-caladea fonts-crosextra-carlito gsfonts lcdf-typetools

# %%
# !git clone https://github.com/amphancm/olmocr.git

#%cd /content/olmocr
#!git switch add-prediction-function
# Out:
# Cloning into 'olmocr'...
# remote: Enumerating objects: 11130, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 11130 (delta 14), reused 0 (delta 0), pack-reused 11104 (from 1)
# Receiving objects: 100% (11130/11130), 116.84 MiB | 28.97 MiB/s, done.
# Resolving deltas: 100% (7348/7348), done.

# %%
# !pip install flash-attn
#!pip install https://download.pytorch.org/whl/cu128/flashinfer/flashinfer_python-0.2.5%2Bcu128torch2.7-cp38-abi3-linux_x86_64.whl

# %%
# %cd /content/olmocr

# !pip install -e .'[gpu]'
#!pip install -e .
# Out:
# /content/olmocr
# Obtaining file:///content/olmocr
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 kB 8.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.0/169.0 kB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 123.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 80.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.0/821.0 MB 2.0 MB/s eta 0:00:00
# ...

# %%
# !pip install sgl-kernel==0.3.5 --force-reinstall --no-deps
# !pip install "sglang[all]==0.5.1"

# %%
# %rm -r /content/olmocr/localworkspace

# %rm -r /content/olmocr/dolma_previews

# %%
# %%time
# %cd /content/olmocr

# !python -m olmocr.pipeline ./localworkspace --pdfs /content/drive/MyDrive/Dataset/pdf-test/*.pdf --model scb10x/typhoon-ocr-3b

# !python -m olmocr.pipeline ./localworkspace --pdfs /content/drive/MyDrive/Dataset/pdf/border.pdf --model Adun/typhoon_ocr-7b-v1.4

# %%
# !python -m olmocr.viewer.dolmaviewer localworkspace/results/output_*.jsonl

# %%
import glob
from IPython.display import Image, display
from IPython.core.display import HTML

for image_path in glob.glob(f'/content/olmocr/dolma_previews/*.html'):
      display(HTML(filename=image_path))
      print("\n")

# %%
#!zip -r dolma_previews_adun.zip /content/olmocr/dolma_previews/
